# %% [markdown]
# # Entrada e saída de dados
#
# Este notebook conterá nossas referências sobre entrada e saída de dados. O pandas pode ler uma variedade de tipos de arquivos usando seus métodos pd.read_. Vejamos os tipos de dados mais comuns:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instale um pacote pip no kernel atual do Jupyter
import  sys
# !{ sys.executable } -m pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('/content/drive/Shareddrives/IFSC/IML/P2. Tratamento de dados com Pandas/exemplo.csv')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### Saída de dados tipo CSV

# %%
df2 = df.copy(True)

# %%
df2
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('/content/drive/Shareddrives/IFSC/IML/P2. Tratamento de dados com Pandas/exemplo_csv_saida_teste.csv',index=False)

# %% [markdown]
# ## Excel
#
# Pandas podem ler e escrever arquivos do Excel, tenha em mente, isso só importa dados. Não fórmulas nem imagens, lembrando que imagens ou macros podem bugar o método.

# %% [markdown]
# ### Entrada via Excel

# %%
df_enad = pd.read_excel('/content/drive/Shareddrives/IFSC/IML/P2. Tratamento de dados com Pandas/conceito_enade_2021.xlsx')

# %%
df_enad
# Out:
#                                                     Ano  Código da Área  \
# 0                                                  2021          2501.0
# 1                                                  2021          2501.0
# 2                                                  2021          2501.0
# 3                                                  2021          2501.0
# 4                                                  2021          2501.0
# ...                                                 ...             ...
# 7995                                               2021            79.0
# 7996                                               2021            79.0
# 7997                                                NaN             NaN
# 7998  * Nome e Sigla da IES atualizados na data da d...             NaN
# 7999  ** Para os cursos na modalidade a distância, o...             NaN
#
#                         Área de Avaliação Grau Acadêmico  Código da IES  \
# 0                          ARTES VISUAIS    Licenciatura            2.0
# 1                          ARTES VISUAIS    Licenciatura            2.0
# 2                          ARTES VISUAIS    Licenciatura            3.0
# 3                          ARTES VISUAIS    Licenciatura            4.0
# 4                          ARTES VISUAIS    Licenciatura            4.0
# ...                                   ...            ...            ...
# 7995  TECNOLOGIA EM REDES DE COMPUTADORES    Tecnológico        15689.0
# 7996  TECNOLOGIA EM REDES DE COMPUTADORES    Tecnológico        15709.0
# 7997                                  NaN            NaN            NaN
# 7998                                  NaN            NaN            NaN
# 7999                                  NaN            NaN            NaN
#
#                                            Nome da IES*  \
# 0                              UNIVERSIDADE DE BRASÍLIA
# 1                              UNIVERSIDADE DE BRASÍLIA
# 2                       UNIVERSIDADE FEDERAL DE SERGIPE
# 3                      UNIVERSIDADE FEDERAL DO AMAZONAS
# 4                      UNIVERSIDADE FEDERAL DO AMAZONAS
# ...                                                 ...
# 7995                   Faculdade de Tecnologia de Bauru
# 7996  Faculdade de Tecnologia de Osasco - Prefeito H...
# 7997                                                NaN
# 7998                                                NaN
# 7999                                                NaN
#
#                                     Sigla da IES* Organização Acadêmica  \
# 0                                             UNB          Universidade
# 1                                             UNB          Universidade
# 2                                             UFS          Universidade
# 3                                            UFAM          Universidade
# 4                                            UFAM          Universidade
# ...                                           ...                   ...
# 7995                                        FATEC             Faculdade
# 7996                                 Fatec Osasco             Faculdade
# 7997                                          NaN                   NaN
# 7998                                          NaN                   NaN
# 7999  do município/UF representa  sede do curso.                    NaN
#
#      Categoria Administrativa  Código do Curso  ... Sigla da UF**   \
# 0             Pública Federal            151.0  ...             DF
# 1             Pública Federal          52159.0  ...             DF
# 2             Pública Federal          80419.0  ...             SE
# 3             Pública Federal          62512.0  ...             AM
# 4             Pública Federal         112126.0  ...             AM
# ...                       ...              ...  ...            ...
# 7995         Pública Estadual        1149804.0  ...             SP
# 7996         Pública Estadual        1177589.0  ...             SP
# 7997                      NaN              NaN  ...            NaN
# 7998                      NaN              NaN  ...            NaN
# 7999                      NaN              NaN  ...            NaN
#
#       Nº de Concluintes Inscritos Nº  de Concluintes Participantes  \
# 0                            54.0                             41.0
# 1                            34.0                             28.0
# 2                            33.0                             33.0
# 3                            27.0                             23.0
# 4                            65.0                             59.0
# ...                           ...                              ...
# 7995                         35.0                             31.0
# 7996                        118.0                             82.0
# 7997                          NaN                              NaN
# 7998                          NaN                              NaN
# 7999                          NaN                              NaN
#
#      Nota Bruta - FG  Nota Padronizada - FG  Nota Bruta - CE  \
# 0             45.814                  3.771           61.907
# 1             40.496                  2.988           51.514
# 2             36.445                  2.392           51.121
# 3             43.569                  3.441           54.447
# 4             25.818                  0.828           33.503
# ...              ...                    ...              ...
# 7995          31.777                  2.629           26.693
# 7996          32.909                  2.808           31.782
# 7997             NaN                    NaN              NaN
# 7998             NaN                    NaN              NaN
# 7999             NaN                    NaN              NaN
#
#       Nota Padronizada - CE  Conceito Enade (Contínuo)  \
# 0                     3.947                      3.903
# 1                     2.640                      2.727
# 2                     2.590                      2.541
# 3                     3.009                      3.117
# 4                     0.374                      0.488
# ...                     ...                        ...
# 7995                  2.018                      2.171
# 7996                  2.690                      2.720
# 7997                    NaN                        NaN
# 7998                    NaN                        NaN
# 7999                    NaN                        NaN
#
#       Conceito Enade (Faixa)  Observação
# 0                          4         NaN
# 1                          3         NaN
# 2                          3         NaN
# 3                          4         NaN
# 4                          1         NaN
# ...                      ...         ...
# 7995                       3         NaN
# 7996                       3         NaN
# 7997                     NaN         NaN
# 7998                     NaN         NaN
# 7999                     NaN         NaN
#
# [8000 rows x 23 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_enad['Código da Área'].plot(kind='hist', bins=20, title='Código da Área')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código da IES'].plot(kind='hist', bins=20, title='Código da IES')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código do Curso'].plot(kind='hist', bins=20, title='Código do Curso')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código do Município**'].plot(kind='hist', bins=20, title='Código do Município**')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_enad.groupby('Ano').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_enad.groupby('Grau Acadêmico').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_enad.groupby('Organização Acadêmica').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_enad.groupby('Categoria Administrativa').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_enad.plot(kind='scatter', x='Código da Área', y='Código da IES', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad.plot(kind='scatter', x='Código da IES', y='Código do Curso', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad.plot(kind='scatter', x='Código do Curso', y='Código do Município**', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad.plot(kind='scatter', x='Código do Município**', y='Nº de Concluintes Inscritos', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_enad['Código da Área'].plot(kind='line', figsize=(8, 4), title='Código da Área')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código da IES'].plot(kind='line', figsize=(8, 4), title='Código da IES')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código do Curso'].plot(kind='line', figsize=(8, 4), title='Código do Curso')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_enad['Código do Município**'].plot(kind='line', figsize=(8, 4), title='Código do Município**')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Grau Acadêmico'].value_counts()
#     for x_label, grp in df_enad.groupby('Ano')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Ano')
# _ = plt.ylabel('Grau Acadêmico')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Organização Acadêmica'].value_counts()
#     for x_label, grp in df_enad.groupby('Grau Acadêmico')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Grau Acadêmico')
# _ = plt.ylabel('Organização Acadêmica')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Categoria Administrativa'].value_counts()
#     for x_label, grp in df_enad.groupby('Organização Acadêmica')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Organização Acadêmica')
# _ = plt.ylabel('Categoria Administrativa')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Modalidade de Ensino'].value_counts()
#     for x_label, grp in df_enad.groupby('Categoria Administrativa')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Categoria Administrativa')
# _ = plt.ylabel('Modalidade de Ensino')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_enad['Ano'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_enad, x='Código da Área', y='Ano', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_enad['Grau Acadêmico'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_enad, x='Código da Área', y='Grau Acadêmico', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_enad['Organização Acadêmica'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_enad, x='Código da Área', y='Organização Acadêmica', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_enad['Categoria Administrativa'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_enad, x='Código da Área', y='Categoria Administrativa', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
df_enad['Código do Município**'].plot(kind='hist', bins=20, title='Código do Município**')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Saída via Excel

# %%
df.to_excel('Exemplo_Excel_Saida.xlsx', sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# Você pode precisar instalar htmllib5, lxml e BeautifulSoup4. No seu terminal / prompt de comando, execute:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Em seguida, reinicie o Jupyter Notebook.
# (Ou use instalação de pip se não estiver usando a Distribuição de Anaconda)
# Pandas podem ler guias de tabelas fora de html. Por exemplo:

# %% [markdown]
# ### Entrada HTML
#
# A função Pandas read_html irá ler tabelas fora de uma página da Web e retornar uma lista de objetos DataFrame:

# %%
#df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
#table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match="Country of origin of first and second-generation immigrants (2023)")

# %%
tabs = pd.read_html("https://www.runnersworld.com/races-places/a20823734/these-are-the-worlds-fastest-marathoners-and-marathon-courses/")

# %%
len(tabs)
tabs
# Out:
# [                             0            1          2               3
#  0                       Runner  Finish Time  Pace/Mile        Marathon
#  1        Kelvin Kiptum (Kenya)      2:00:35     4:36.0   Chicago, 2023
#  2       Eliud Kipchoge (Kenya)      2:01:09     4:37.2    Berlin, 2022
#  3   Kenenisa Bekele (Ethiopia)      2:01:41     4:38.5    Berlin, 2019
#  4       Sisay Lemma (Ethiopia)      2:01:48     4:38.7  Valencia, 2023
#  5       Sabastian Sawe (Kenya)      2:02:05     4:39.4  Valencia, 2024
#  6       Benson Kipruto (Kenya)      2:02:16     4:39.8     Tokyo, 2024
#  7     Deresa Geleta (Ethiopia)      2:02:38     4:40.6  Valencia, 2024
#  8           John Korir (Kenya)      2:02:44     4:40.8   Chicago, 2024
#  9    Birhanu Legese (Ethiopia)      2:02:48     4:41.0    Berlin, 2019
#  10  Mosinet Geremew (Ethiopia)      2:02:55     4:41.3    London, 2019,
#                                    0            1          2               3
#  0                            Runner  Finish Time  Pace/Mile        Marathon
#  1          Ruth Chepngetich (Kenya)      2:09:56     4:57.4   Chicago, 2024
#  2          Tigist Assefa (Ethiopia)      2:11:53     5:01.8    Berlin, 2023
#  3        Sifan Hassan (Netherlands)      2:13:44     5:06.0   Chicago, 2023
#  4             Brigid Kosgei (Kenya)      2:14:04     5:06.8   Chicago, 2019
#  5                               NaN          NaN        NaN             NaN
#  6           Amane Beriso (Ethiopia)      2:14:58     5:08.9  Valencia, 2022
#  7   Paula Radcliffe (Great Britain)      2:15:25     5:09.9    London, 2003
#  8        Worknesh Degefa (Ethiopia)      2:15:51     5:10.9  Valencia, 2023
#  9          Sutume Kebede (Ethiopia)      2:15:55     5:11.0     Tokyo, 2024
#  10         Tigist Ketema (Ethiopia)      2:16:07     5:11.5     Dubai, 2024
#  11         Rosemary Wanjiru (Kenya)      2:16:14     5:11.8     Tokyo, 2024
#  12                              NaN          NaN        NaN             NaN,
#                      0            1          2                3
#  0              Runner  Finish Time  Pace/Mile         Marathon
#  1   Khalid Khannouchi      2:05:38     4:47.5     London, 2002
#  2          Galen Rupp      2:06:07     4:48.6     Prague, 2018
#  3           Ryan Hall      2:06:17     4:49.0     London, 2008
#  4       Biya Simbassa      2:06:53     4:50.4   Valencia, 2024
#  5   Dathan Ritzenhein      2:07:47     4:52.4    Chicago, 2012
#  6        Conner Mantz      2:07:47     4:52.4    Chicago, 2023
#  7       Leonard Korir      2:07:56     4:52.8  Amsterdam, 2019
#  8       Clayton Young      2:08:00     4:52.9    Chicago, 2023
#  9        CJ Albertson      2:08:17     4:53.6    Chicago, 2024
#  10       Sam Chelanga      2:08:50     4:54.8    Chicago, 2023,
#                     0            1          2                           3
#  0             Runner  Finish Time  Pace/Mile                    Marathon
#  1       Emily Sisson      2:18:29     5:16.9               Chicago, 2022
#  2      Keira D’Amato      2:19:12     5:18.6               Houston, 2022
#  3        Betsy Saina      2:19:17     5:18.7                 Tokyo, 2024
#  4       Deena Kastor      2:19:36     5:19.5                London, 2006
#  5          Sara Hall      2:20:32     5:21.6  The Marathon Project, 2020
#  6       Jordan Hasay      2:20:57     5:22.6               Chicago, 2017
#  7   Shalane Flanagan      2:21:14     5:23.2                Berlin, 2014
#  8     Joan Samuelson      2:21:21     5:23.5               Chicago, 1985
#  9          Amy Cragg      2:21:42     5:24.3                 Tokyo, 2018
#  10  Susanna Sullivan      2:21:56     5:24.8               Chicago, 2024,
#                               0            1          2               3
#  0                       Runner  Finish Time  Pace/Mile        Marathon
#  1        Kelvin Kiptum (Kenya)      2:00:35     4:36.0   Chicago, 2023
#  2       Eliud Kipchoge (Kenya)      2:01:09     4:37.2    Berlin, 2022
#  3        Kelvin Kiptum (Kenya)      2:01:25     4:37.8    London, 2023
#  4       Eliud Kipchoge (Kenya)      2:01:39     4:38.4    Berlin, 2018
#  5   Kenenisa Bekele (Ethiopia)      2:01:41     4:38.5    Berlin, 2019
#  6       Sisay Lemma (Ethiopia)      2:01:48     4:38.7  Valencia, 2023
#  7        Kelvin Kiptum (Kenya)      2:01:53     4:38.9  Valencia, 2022
#  8       Sabastian Sawe (Kenya)      2:02:05     4:39.4  Valencia, 2024
#  9       Benson Kipruto (Kenya)      2:02:16     4:39.8     Tokyo, 2024
#  10      Eliud Kipchoge (Kenya)      2:02:37     4:40.6    London, 2019
#  11                         NaN          NaN        NaN             NaN,
#                                    0            1          2               3
#  0                            Runner  Finish Time  Pace/Mile        Marathon
#  1          Ruth Chepngetich (Kenya)      2:09:56     4:57.4   Chicago, 2024
#  2          Tigist Assefa (Ethiopia)      2:11:53     5:01.8    Berlin, 2023
#  3        Sifan Hassan (Netherlands)      2:13:44     5:06.0   Chicago, 2023
#  4             Brigid Kosgei (Kenya)      2:14:04     5:06.8   Chicago, 2019
#  5          Ruth Chepngetich (Kenya)      2:14:18     5:07.3   Chicago, 2022
#  6           Amane Beriso (Ethiopia)      2:14:58     5:08.9  Valencia, 2022
#  7   Paula Radcliffe (Great Britain)      2:15:25     5:09.9    London, 2003
#  8          Tigist Assefa (Ethiopia)      2:15:37     5:10.3    Berlin, 2022
#  9          Ruth Chepngetich (Kenya)      2:15:37     5:10.3   Chicago, 2023
#  10       Worknesh Gedefa (Ethiopia)      2:15:51     5:10.9  Valencia, 2023,
#                                      0            1          2                3
#  0                              Runner  Finish Time  Pace/Mile         Marathon
#  1         Belayneh Densamo (Ethiopia)      2:06:50     4:50.3  Rotterdam, 1988
#  2           Ronaldo da Costa (Brazil)      2:06:06     4:48.6     Berlin, 1998
#  3         Khalid Khannouchi (Morocco)      2:05:42     4:47.7    Chicago, 1999
#  4   Khalid Khannouchi (United States)      2:05:38     4:47.5     London, 2002
#  5                 Paul Tergat (Kenya)      2:04:55     4:45.9     Berlin, 2003
#  6       Haile Gebrselassie (Ethiopia)      2:04:26     4:44.8     Berlin, 2007
#  7       Haile Gebrselassie (Ethiopia)      2:03:59     4:43.8     Berlin, 2008
#  8               Patrick Makau (Kenya)      2:03:38     4:43.0     Berlin, 2011
#  9              Wilson Kipsang (Kenya)      2:03:23     4:42.4     Berlin, 2013
#  10             Dennis Kimetto (Kenya)      2:02:57     4:41.4     Berlin, 2014
#  11             Eliud Kipchoge (Kenya)      2:01:39     4:38.4     Berlin, 2018
#  12             Eliud Kipchoge (Kenya)      2:01:09     4:37.2     Berlin, 2022
#  13              Kelvin Kiptum (Kenya)      2:00:35     4:36.0    Chicago, 2023,
#                                   0            1          2                3
#  0                           Runner  Finish Time  Pace/Mile         Marathon
#  1            Tegla Loroupe (Kenya)      2:20:47     5:22.2  Rotterdam, 1998
#  2            Tegla Loroupe (Kenya)      2:20:43     5:22.0     Berlin, 1999
#  3          Naoko Takahashi (Japan)      2:19:46     5:19.8     Berlin, 2001
#  4        Catherine Ndereba (Kenya)      2:18:47     5:17.6    Chicago, 2001
#  5  Paula Radcliffe (Great Britain)      2:17:18     5:14.2    Chicago, 2002
#  6  Paula Radcliffe (Great Britain)      2:15:25     5:09.9     London, 2003
#  7            Brigid Kosgei (Kenya)      2:14:04     5:06.8    Chicago, 2019
#  8         Tigist Assefa (Ethiopia)      2:11:53     5:01.8     Berlin, 2023
#  9         Ruth Chepngetich (Kenya)      2:09:56     4:47.4    Chicago, 2024]

# %%
tabs[2]
# Out:
#                     0            1          2                3
# 0              Runner  Finish Time  Pace/Mile         Marathon
# 1   Khalid Khannouchi      2:05:38     4:47.5     London, 2002
# 2          Galen Rupp      2:06:07     4:48.6     Prague, 2018
# 3           Ryan Hall      2:06:17     4:49.0     London, 2008
# 4       Biya Simbassa      2:06:53     4:50.4   Valencia, 2024
# 5   Dathan Ritzenhein      2:07:47     4:52.4    Chicago, 2012
# 6        Conner Mantz      2:07:47     4:52.4    Chicago, 2023
# 7       Leonard Korir      2:07:56     4:52.8  Amsterdam, 2019
# 8       Clayton Young      2:08:00     4:52.9    Chicago, 2023
# 9        CJ Albertson      2:08:17     4:53.6    Chicago, 2024
# 10       Sam Chelanga      2:08:50     4:54.8    Chicago, 2023

# %% [markdown]
# ____
