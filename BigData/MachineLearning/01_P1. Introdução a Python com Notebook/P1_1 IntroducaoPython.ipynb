# %% [markdown]
# # Curso rápido de Python
#
#
# * Numbers
# * Strings
# * Printando
# * Listas
# * Dicionários
# * Boleanos
# * Tuplas
# * Sets
#
#
# * Operadores de comparação
# * if,elif, else
# * for Loops
# * while Loops
# * range()
# * Cláusulas break, continuee elseem Laços
# * list comprehension
# * funções
# * expressões lamda
# * map e filter
# * métodos
# ____

# %%
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/Shareddrives/IFSC/IML/P1. Introdução a Python com Notebook/P1_2 IntroducaoNumPy.ipynb

# %% [markdown]
# ## Tipos de dados

# %% [markdown]
# ### Numéricos

# %%
1+3
# Out:
# 4

# %%
2 * 3
# Out:
# 6

# %%
6 / 2
# Out:
# 3.0

# %%
5 ** 3
# Out:
# 125

# %%
9 % 2
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
11 % 3
# Out:
# 2

# %%
(3 + 3) * 4 + 4
# Out:
# 28

# %% [markdown]
# ### Definição de variáveis

# %%
# Não se pode iniciar uma variável com números ou carateres especais
nome_da_variavel = 2

# %%
x = 3
y = 5
z = x + y
print(z)
x
# Out:
# 8
# 3

# %% [markdown]
# ### Strings

# %%
'Citação simples'
# Out:
# 'Citação simples'

# %%
"Citações duplas"
# Out:
# 'Citações duplas'

# %%
variavel1 = "texto"
variavel2 = 'texto'

# %% [markdown]
# ### Printando

# %%
var1 = 'ola'
var1
# Out:
# 'ola'

# %%
print(var1)
print(var1)
print(var1)
print(var1)
# Out:
# ola
# ola
# ola
# ola

# %%
idade = 44
nome = 'Glauco'
sobrenome = "Cardozo"
altura=1
type(nome)
# Out:
# str

# %%
print('Me chamo {v1} {v2} e tenho: {v3}'.format(v1=nome,v2=sobrenome,v3=idade))
# Out:
# Me chamo Glauco Cardozo e tenho: 44

# %% [markdown]
# ### Listas
#
# Python possui diversas estruturas de dados nativas, utilizadas para agrupar outros valores. A mais versátil delas é a lista (list), que pode ser escrita como uma lista de valores
# separados por vírgula e entre colchetes. Mais importante, os valores contidos na lista não precisam ser do mesmo tipo.

# %%
lista = [1, 2, 3, 4, 5, 6]
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista.append(7)
lista.index(7)
# Out:
# 6

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
lista.index(3)
# Out:
# 2

# %%
lista[2]
type(lista)
# Out:
# list

# %%
lista2 = ['hi',1,[1,2, 'olas']]
lista2
# Out:
# ['hi', 1, [1, 2, 'olas']]

# %%
lista2[2][2][3]
# Out:
# 's'

# %%
minha_lista = ['a','b','c']

# %%
minha_lista.append('d')

# %%
minha_lista
# Out:
# ['a', 'b', 'c', 'd']

# %%
minha_lista[0]
# Out:
# 'a'

# %%
minha_lista[1]
# Out:
# 'b'

# %%
minha_lista[1:3]
# Out:
# ['b', 'c']

# %%
minha_lista.append('e')
minha_lista
# Out:
# ['NOVO', 'b', 'c', 'd', 'e', 'e']

# %%
minha_lista[0] = 'NOVO'
minha_lista[5] = 'f'

# %%
minha_lista
# Out:
# ['NOVO', 'b', 'c', 'd', 'e', 'f']

# %%
string = "nome sobrenome"
string[:10]
# Out:
# 'nome sobre'

# %%
minha_lista
# Out:
# ['NOVO', 'b', 'c', 'd', 'e', 'f']

# %%
minha_lista[0][:2]
# Out:
# 'NO'

# %%
#lista aninhada

lista_aninhada = [1,2,3,[4,5,'target']]

# %%
lista_aninhada[3][2][2:4]
# Out:
# 'rg'

# %%
lista_aninhada[3][2]
# Out:
# 'target'

# %%
lista_aninhada[3][2][0]
# Out:
# 't'

# %%
pilha = [3, 4, 5]
pilha.append(6)
pilha.append(7)
pilha
# Out:
# [3, 4, 5, 6, 7]

# %%
pilha.pop()
pilha
# Out:
# [3, 4, 5, 6]

# %%
fila = [3, 4, 5]
fila.append(6)
fila.append(7)
fila.pop(0)
fila
# Out:
# [4, 5, 6, 7]

# %% [markdown]
# ### Dicionários
#
# Tipo de lista com indexação

# %%
d = {'chave1':'item1','chave2':'item2'}
d
# Out:
# {'chave1': 'item1', 'chave2': 'item2'}

# %%
d['chave1']
# Out:
# 'item1'

# %%
d = {'chave1':['item1.1','item1.2','item1.3'],'chave2':['item2.1','item2.2','item2.3']}

# %%
d['chave1']
# Out:
# ['item1.1', 'item1.2', 'item1.3']

# %% [markdown]
# ### Tuplas

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
lista[0]=22
lista
# Out:
# [22, 2, 3, 4, 5, 6, 7]

# %%
tupla = (1,2,3)

# %%
tupla[0]
# Out:
# 1

# %%
tupla[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 tupla[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Sets
#
# Python também inclui um tipo de dados para conjuntos (sets). Um conjunto é uma coleção desordenada de dados, sem elementos duplicados. Usos comuns para isso incluem
# verificações da existência de objetos em outros sequências e eliminação de items duplicados. Conjuntos também suportam operações matemáticas como união, interseção,
# diferença e diferença simétrica.

# %%
vs1 = {1,2,3}
vs1
# Out:
# {1, 2, 3}

# %%
vs2 = {1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}
vs2
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Booleanos

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
1==1
# Out:
# True

# %%
(1!=1) and (1<2)
# Out:
# True

# %% [markdown]
# ## Operadores de comparação

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
'oi' == 'tchau'
# Out:
# False

# %% [markdown]
# ## Operadores lógicos

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %% [markdown]
# ## if,elif, else

# %%
if 3 > 2:

  print('Sim!')


print('Nao!')
# Out:
# Sim!
# Nao!

# %%
if 1 < 2:
  print('Primeiro')
else:
  print('Último')

  print('Nao!')
# Out:
# Primeiro

# %%
if 1 > 2:
    print('Primeiro')
else:
    print('Último')
# Out:
# Último

# %%
if 1 == 2:
    print('Primeiro')
elif 3 == 3:
    print('Meio')
else:
    print('Último')
# Out:
# Meio

# %%
#if ternário

numero = 6
msg = "Par" if numero%2 == 0 else "Impar"
print(msg)
# Out:
# Par

# %% [markdown]
# ## for Loops

# %%
seq = {1,2,3,4,5}
seq
# Out:
# {1, 2, 3, 4, 5}

# %%
for iten in d:
    print(d[iten])
# Out:
# ['item1.1', 'item1.2', 'item1.3']
# ['item2.1', 'item2.2', 'item2.3']

# %%
for item in seq:
    print('!')
# Out:
# !
# !
# !
# !
# !

# %%
for outra_coisa in seq:
    print(outra_coisa+outra_coisa)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## while Loops

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %% [markdown]
# ## range()
#
# Se você precisar iterar sobre sequências numéricas, a função interna range()é a resposta. Ela gera listas contendo progressões aritiméticas, por exemplo:

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lista1 = list(range(5))
lista1
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Cláusulas break, continuee else em Laços

# %%
a= list(range(2, 10))
a
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print(n, 'equals', x, '*', n/x)
            break
    else:
        # loop caiu sem encontrar um fator
        print(n, 'is a prime number')
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 equals 2 * 2.0
# 5 is a prime number
# 6 equals 2 * 3.0
# 7 is a prime number
# 8 equals 2 * 4.0
# 9 equals 3 * 3.0

# %% [markdown]
# ## Abrangência de Lista (List Comprehensions)
#
# Abrangência de listas (ou list comprehensions) permitem a criação de listas de forma concisa sem apelar para o uso de map(), filter()e/ou lambda. A definição resultante
# tende a ser mais clara do que o uso das construções funcionais citadas anteriormente. Cada abrangência de lista consiste numa expressão seguida da cláusula for, e então
# zero ou mais cláusulas forou if. O resultado será uma lista proveniente da avaliação da expressão no contexto das cláusulas fore ifsubsequentes. Se a expressão gerar
# uma tupla, a mesma deve ser inserida entre parênteses

# %%
x = [1,2,3,4]

# %%
out = []
for item in x:
    out.append(item**2)
print(out)
# Out:
# [1, 4, 9, 16]

# %%
for item in x:
  print(item)
# Out:
# 1
# 2
# 3
# 4

# %%
lista1 = [item**2 for item in x]
print(lista1)

lista2 = [item for item in range(5)]
lista2
# Out:
# [1, 4, 9, 16]
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## Funções

# %%
def my_func(param1='valor1', param2='valor2'):
    """
    Documentação da função vai aqui.
    """
    #sdfgsfg
    print(param1)
    print(param2)

# %%
my_func(param2=2, param1=5)
# Out:
# 5
# 2

# %%
my_func()
# Out:
# default
# default2

# %%
my_func(param2='novo parametro')
# Out:
# default
# novo parametro

# %%
my_func(param1='novo parametro')
# Out:
# novo parametro

# %%
def square(x):
    return x**2

# %%
out = square(2)
print(out)
# Out:
# 4

# %%
def funcao(x, y):

    a = x+y;
    b = x*y;

    return a, b

# %%
A, B = funcao(2, 3)
print(A)
print(B)
# Out:
# 5
# 6

# %% [markdown]
# ## Expressões lamda

# %%
def vezes2(var):
    return var*2

# %%
vezes2(2)
# Out:
# 4

# %%
lambda var: var*2
# Out:
# <function __main__.<lambda>(var)>

# %% [markdown]
# ## map e filter

# %%
seq = [1,2,3,4,5]

# %%
#extração

map(vezes2,seq)

# %%
list(map(vezes2,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(lambda var: var*2,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(lambda var: var%2,seq))
# Out:
# [1, 0, 1, 0, 1]

# %%
#comparação

filter(lambda item: item%2 == 0, seq)

# %%
list(filter(lambda item: item%2 != 0, seq))
# Out:
# [1, 3, 5]

# %% [markdown]
# ## Métodos

# %%
st = 'Olá, me chamo Glauco Cardozo'

# %%
# coloca todo o texto em lowercase
st.lower()
# Out:
# 'olá, me chamo glauco cardozo'

# %%
# coloca todo o texto em upercase
st.upper()
# Out:
# 'OLÁ, ME CHAMO GLAUCO CARDOZO'

# %%
#quebra a string em partes formando uma lista
st.split()
# Out:
# ['Olá,', 'me', 'chamo', 'Glauco', 'Cardozo']

# %%
lista_st = st.split()
lista_st[3]
# Out:
# 'Glauco'

# %%
tweet = 'Dale Avai! #Avai1 #Avai2'

# %%
tweet.split('#')
# Out:
# ['Dale Avai! ', 'Avai1 ', 'Avai2']

# %%
tweet.split('#')[1]
# Out:
# 'Avai1 '

# %%
d
# Out:
# {'chave1': ['item1.1', 'item1.2', 'item1.3'],
#  'chave2': ['item2.1', 'item2.2', 'item2.3']}

# %%
d.keys()
# Out:
# dict_keys(['chave1', 'chave2'])

# %%
d.items()
# Out:
# dict_items([('chave1', ['item1.1', 'item1.2', 'item1.3']), ('chave2', ['item2.1', 'item2.2', 'item2.3'])])

# %%
lst = [1,2,3]

# %%
#remove elemento da lista

print(lst.pop())
lst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-cf91fe8dab46> in <cell line: 3>()
#       1 #remove elemento da lista
#       2
# ----> 3 print(lst.pop())
#       4 lst
#
# NameError: name 'lst' is not defined

# %%
lst.append(4)

# %%
lst
# Out:
# [1, 2, 4]

# %%
'x' in [1,2,3]
# Out:
# False

# %%
'x' in ['x','y','z']
# Out:
# True

# %%
ola = "Helo world"
ola
# Out:
# 'Helo world'

# %%
for letra in ola:
  print(letra)
# Out:
# H
# e
# l
# o
#
# w
# o
# r
# l
# d

# %%
# prompt: como faço para imprimir a variavel ola de tras pra frente?

ola = "Helo world"
print(ola[::-1])
# Out:
# dlrow oleH
